# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Laden Datensatzes
taxi_data = sns.load_dataset("tips")
print(taxi_data.head())

# Speichern des Datensatzes in einer CSV-Datei
#taxi_data.to_csv("taxi_data.csv", index=False)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Erstellen der neuen Spalte "total" mit Addition aus "total-bill" und "tip"
taxi_data["total"] = taxi_data["total_bill"] + taxi_data["tip"]
taxi_data
# Out:
#      total_bill   tip     sex smoker   day    time  size  total
# 0         16.99  1.01  Female     No   Sun  Dinner     2  18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3  12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3  24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2  26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4  28.20
# ..          ...   ...     ...    ...   ...     ...   ...    ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2  19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2  21.78
#
# [244 rows x 8 columns]

# %%
# Erstellen des Boxplots für "total"
plt.figure(figsize=(8, 6))
sns.boxplot(x="total", data=taxi_data)
plt.title("Boxplot von Total")
plt.xlabel("Total")
plt.show()
